# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
#%matplotlib inline

# %%
df1 = pd.read_csv("2020/october/yellow_tripdata_2020-10.csv" , low_memory=False)
df1
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-10-01 00:09:08   2020-10-01 00:11:05              1.0
# 1             1.0  2020-10-01 00:09:19   2020-10-01 00:19:46              1.0
# 2             1.0  2020-10-01 00:30:00   2020-10-01 00:39:05              1.0
# 3             2.0  2020-10-01 00:56:46   2020-10-01 00:57:10              1.0
# 4             2.0  2020-10-01 00:56:46   2020-10-01 00:57:10              1.0
# ...           ...                  ...                   ...              ...
# 1681126       NaN  2020-10-05 18:41:00   2020-10-05 19:11:00              NaN
# 1681127       NaN  2020-10-05 18:02:09   2020-10-05 18:51:48              NaN
# 1681128       NaN  2020-10-05 18:06:48   2020-10-05 18:17:53              NaN
# 1681129       NaN  2020-10-05 18:48:50   2020-10-05 19:05:08              NaN
# 1681130       NaN  2020-10-05 18:07:00   2020-10-05 18:41:00              NaN
#
# ...

# %%
df2 = df1.dropna()
df2
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-10-01 00:09:08   2020-10-01 00:11:05              1.0
# 1             1.0  2020-10-01 00:09:19   2020-10-01 00:19:46              1.0
# 2             1.0  2020-10-01 00:30:00   2020-10-01 00:39:05              1.0
# 3             2.0  2020-10-01 00:56:46   2020-10-01 00:57:10              1.0
# 4             2.0  2020-10-01 00:56:46   2020-10-01 00:57:10              1.0
# ...           ...                  ...                   ...              ...
# 1575213       2.0  2020-10-31 23:11:43   2020-10-31 23:15:21              1.0
# 1575214       2.0  2020-10-31 23:19:11   2020-10-31 23:19:39              1.0
# 1575215       2.0  2020-10-31 23:30:11   2020-11-01 00:06:20              1.0
# 1575216       2.0  2020-10-31 23:09:36   2020-10-31 23:15:34              2.0
# 1575217       2.0  2020-10-31 23:32:03   2020-10-31 23:41:56              1.0
#
# ...

# %%
df2.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  1.575218e+06     1.575218e+06   1.575218e+06  1.575218e+06
# mean   1.684070e+00     1.426552e+00   2.535423e+00  1.027878e+00
# std    4.648852e-01     1.064304e+00   7.941405e+01  5.614400e-01
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.000000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.610000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   2.740000e+00  1.000000e+00
# max    2.000000e+00     9.000000e+00   9.960311e+04  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  1.575218e+06  1.575218e+06  1.575218e+06  1.575218e+06  1.575218e+06
# mean   1.664058e+02  1.635731e+02  1.273199e+00  1.171162e+01  1.011595e+00
# std    6.679436e+01  7.111641e+01  4.836505e-01  7.954652e+02  1.218438e+00
# ...

# %%
df2.shape
# Out:
# (1575218, 18)

# %%
def remove_pps_outliers(df2):
    df_out = pd.DataFrame()
    for key, subdf in df2.groupby('VendorID'):
        m = np.mean(subdf.trip_distance)
        st = np.std(subdf.trip_distance)
        reduced_df = subdf[(subdf.trip_distance> 0 ) & (subdf.trip_distance<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df3 = remove_pps_outliers(df2)
df3.shape
# Out:
# (1510521, 18)

# %%
df3.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  1.510521e+06     1.510521e+06   1.510521e+06  1.510521e+06
# mean   1.708380e+00     1.437518e+00   2.309853e+00  1.015372e+00
# std    4.545084e-01     1.075797e+00   2.632248e+00  3.878723e-01
# min    1.000000e+00     0.000000e+00   1.000000e-02  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.000000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.600000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   2.630000e+00  1.000000e+00
# max    2.000000e+00     9.000000e+00   9.831000e+01  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  1.510521e+06  1.510521e+06  1.510521e+06  1.510521e+06  1.510521e+06
# mean   1.670352e+02  1.642793e+02  1.268254e+00  1.107462e+01  9.835333e-01
# std    6.675577e+01  7.066480e+01  4.755705e-01  8.123040e+02  1.198848e+00
# ...

# %%
def remove_pps_outliers(df3):
    df_out = pd.DataFrame()
    for key, subdf2 in df3.groupby('VendorID'):
        m = np.mean(subdf2.total_amount)
        st = np.std(subdf2.total_amount)
        reduced_df = subdf2[(subdf2.total_amount> 0 ) & (subdf2.total_amount<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df4 = remove_pps_outliers(df3)
df4.shape
# Out:
# (1409618, 18)

# %%
df4.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  1.409618e+06     1.409618e+06   1.409618e+06  1.409618e+06
# mean   1.687522e+00     1.429123e+00   1.814627e+00  1.004001e+00
# std    4.635035e-01     1.067473e+00   1.159756e+00  3.557331e-01
# min    1.000000e+00     0.000000e+00   1.000000e-02  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   9.700000e-01  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.510000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   2.380000e+00  1.000000e+00
# max    2.000000e+00     9.000000e+00   8.408000e+01  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  1.409618e+06  1.409618e+06  1.409618e+06  1.409618e+06  1.409618e+06
# mean   1.679961e+02  1.655914e+02  1.261236e+00  9.029995e+00  1.028446e+00
# std    6.686024e+01  6.979743e+01  4.563084e-01  3.993722e+00  1.214605e+00
# ...

# %%
def remove_pps_outliers(df4):
    df_out = pd.DataFrame()
    for key, subdf3 in df4.groupby('RatecodeID'):
        m = np.mean(subdf3.RatecodeID)
        st = np.std(subdf3.RatecodeID)
        reduced_df = subdf3[(subdf3.RatecodeID> 0 ) & (subdf3.RatecodeID<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df5 = remove_pps_outliers(df4)
df5.shape
# Out:
# (1409618, 18)

# %%
df5.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  1.409618e+06     1.409618e+06   1.409618e+06  1.409618e+06
# mean   1.687522e+00     1.429123e+00   1.814627e+00  1.004001e+00
# std    4.635035e-01     1.067473e+00   1.159756e+00  3.557331e-01
# min    1.000000e+00     0.000000e+00   1.000000e-02  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   9.700000e-01  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.510000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   2.380000e+00  1.000000e+00
# max    2.000000e+00     9.000000e+00   8.408000e+01  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  1.409618e+06  1.409618e+06  1.409618e+06  1.409618e+06  1.409618e+06
# mean   1.679961e+02  1.655914e+02  1.261236e+00  9.029995e+00  1.028446e+00
# std    6.686024e+01  6.979743e+01  4.563084e-01  3.993722e+00  1.214605e+00
# ...

# %%
index_names = df5[ df5['RatecodeID'] == 99.0 ].index

# %%
drop_A=df5.index[df5['RatecodeID'] == 99.0].tolist()
df6=df5.drop(df5.index[drop_A])

# %%
df6.shape
# Out:
# (1409601, 18)

# %%
df6.RatecodeID.describe()
# Out:
# count    1.409601e+06
# mean     1.002819e+00
# std      1.035850e-01
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      6.000000e+00
# Name: RatecodeID, dtype: float64

# %%
df6 = df5.assign(final_amount= (df5.fare_amount + df5.extra + df5.mta_tax + df5.tip_amount + df5.tolls_amount + df5.improvement_surcharge + df5.congestion_surcharge ))

# %%
df6
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-10-01 00:09:19   2020-10-01 00:19:46              1.0
# 1             1.0  2020-10-01 00:30:00   2020-10-01 00:39:05              1.0
# 2             1.0  2020-10-01 00:31:00   2020-10-01 00:37:58              1.0
# 3             1.0  2020-10-01 00:37:04   2020-10-01 00:39:07              0.0
# 4             1.0  2020-10-01 00:38:44   2020-10-01 00:51:40              1.0
# ...           ...                  ...                   ...              ...
# 1409613       2.0  2020-10-27 12:44:48   2020-10-27 12:54:42              1.0
# 1409614       2.0  2020-10-28 07:52:13   2020-10-28 07:58:51              1.0
# 1409615       2.0  2020-10-29 10:50:33   2020-10-29 11:06:54              1.0
# 1409616       2.0  2020-10-30 10:40:17   2020-10-30 10:56:15              1.0
# 1409617       2.0  2020-10-30 15:35:28   2020-10-30 15:45:24              1.0
#
# ...

# %%
df7 = df6.drop(['extra' , 'mta_tax' , 'tip_amount' , 'tolls_amount' , 'improvement_surcharge' , 'total_amount' , 'congestion_surcharge'] , axis=1)

# %%
df7
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-10-01 00:09:19   2020-10-01 00:19:46              1.0
# 1             1.0  2020-10-01 00:30:00   2020-10-01 00:39:05              1.0
# 2             1.0  2020-10-01 00:31:00   2020-10-01 00:37:58              1.0
# 3             1.0  2020-10-01 00:37:04   2020-10-01 00:39:07              0.0
# 4             1.0  2020-10-01 00:38:44   2020-10-01 00:51:40              1.0
# ...           ...                  ...                   ...              ...
# 1409613       2.0  2020-10-27 12:44:48   2020-10-27 12:54:42              1.0
# 1409614       2.0  2020-10-28 07:52:13   2020-10-28 07:58:51              1.0
# 1409615       2.0  2020-10-29 10:50:33   2020-10-29 11:06:54              1.0
# 1409616       2.0  2020-10-30 10:40:17   2020-10-30 10:56:15              1.0
# 1409617       2.0  2020-10-30 15:35:28   2020-10-30 15:45:24              1.0
#
# ...

# %%
def remove_pps_outliers(df7):
    df_out = pd.DataFrame()
    for key, subdf7 in df7.groupby('VendorID'):
        m = np.mean(subdf7.passenger_count)
        st = np.std(subdf7.passenger_count)
        reduced_df = subdf7[(subdf7.passenger_count> 0 )]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df8 = remove_pps_outliers(df7)
df8.shape
# Out:
# (1380322, 12)

# %%
plt.scatter(df7.final_amount, df7.trip_distance)
plt.xlabel('final_amount')
plt.ylabel('trip_distance')
plt.title('trip_distance vs final_amount')
plt.show()

# %%
def remove_pps_outliers(df7):
    df_out = pd.DataFrame()
    for key, subdf7 in df7.groupby('VendorID'):
        m = np.mean(subdf7.final_amount)
        st = np.std(subdf7.final_amount)
        reduced_df = subdf7[(subdf7.final_amount> 0 ) & (subdf7.final_amount<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df8 = remove_pps_outliers(df7)
df8.shape
# Out:
# (1181571, 12)

# %%
df8
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-10-01 00:09:19   2020-10-01 00:19:46              1.0
# 1             1.0  2020-10-01 00:30:00   2020-10-01 00:39:05              1.0
# 2             1.0  2020-10-01 00:31:00   2020-10-01 00:37:58              1.0
# 3             1.0  2020-10-01 00:37:04   2020-10-01 00:39:07              0.0
# 4             1.0  2020-10-01 00:38:44   2020-10-01 00:51:40              1.0
# ...           ...                  ...                   ...              ...
# 1181566       2.0  2020-10-27 12:44:48   2020-10-27 12:54:42              1.0
# 1181567       2.0  2020-10-28 07:52:13   2020-10-28 07:58:51              1.0
# 1181568       2.0  2020-10-29 10:50:33   2020-10-29 11:06:54              1.0
# 1181569       2.0  2020-10-30 10:40:17   2020-10-30 10:56:15              1.0
# 1181570       2.0  2020-10-30 15:35:28   2020-10-30 15:45:24              1.0
#
# ...

# %%
def remove_pps_outliers(df8):
    df_out = pd.DataFrame()
    for key, subdf8 in df8.groupby('VendorID'):
        m = np.mean(subdf8.passenger_count)
        st = np.std(subdf8.passenger_count)
        reduced_df = subdf8[(subdf8.passenger_count> 0 )]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df9 = remove_pps_outliers(df8)
df9.shape
# Out:
# (1156392, 12)

# %%
df9
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-10-01 00:09:19   2020-10-01 00:19:46              1.0
# 1             1.0  2020-10-01 00:30:00   2020-10-01 00:39:05              1.0
# 2             1.0  2020-10-01 00:31:00   2020-10-01 00:37:58              1.0
# 3             1.0  2020-10-01 00:38:44   2020-10-01 00:51:40              1.0
# 4             1.0  2020-10-01 00:38:49   2020-10-01 00:42:03              1.0
# ...           ...                  ...                   ...              ...
# 1156387       2.0  2020-10-27 12:44:48   2020-10-27 12:54:42              1.0
# 1156388       2.0  2020-10-28 07:52:13   2020-10-28 07:58:51              1.0
# 1156389       2.0  2020-10-29 10:50:33   2020-10-29 11:06:54              1.0
# 1156390       2.0  2020-10-30 10:40:17   2020-10-30 10:56:15              1.0
# 1156391       2.0  2020-10-30 15:35:28   2020-10-30 15:45:24              1.0
#
# ...

# %%
df9[['tpep_pickup_datetime', 'tpep_dropoff_datetime']] = df9[['tpep_pickup_datetime', 'tpep_dropoff_datetime']].apply(pd.to_datetime)

# %%
df9['new_pickup_date'] = [d.date() for d in df9['tpep_pickup_datetime']]
df9['new_pickup_time'] = [d.time() for d in df9['tpep_pickup_datetime']]

# %%
df9['new_dropoff_date'] = [d.date() for d in df9['tpep_dropoff_datetime']]
df9['new_dropoff_time'] = [d.time() for d in df9['tpep_dropoff_datetime']]

# %%
df9.drop(columns=['tpep_pickup_datetime','tpep_dropoff_datetime'])
# Out:
#          VendorID  passenger_count  trip_distance  RatecodeID  \
# 0             1.0              1.0           2.00         1.0
# 1             1.0              1.0           2.10         1.0
# 2             1.0              1.0           1.50         1.0
# 3             1.0              1.0           3.80         1.0
# 4             1.0              1.0           1.60         1.0
# ...           ...              ...            ...         ...
# 1156387       2.0              1.0           0.83        99.0
# 1156388       2.0              1.0           0.97        99.0
# 1156389       2.0              1.0           1.93        99.0
# 1156390       2.0              1.0           2.04        99.0
# 1156391       2.0              1.0           1.68        99.0
#
#         store_and_fwd_flag  PULocationID  DOLocationID  payment_type  \
# 0                        Y           238           143           2.0
# 1                        N           264           230           1.0
# ...

# %%
df10 = df9

# %%
column_names = ["VendorID", "new_pickup_date", "new_dropoff_date" , "new_pickup_time" , "new_dropoff_time" , "passenger_count" , "trip_distance" , "RatecodeID" , "store_and_fwd_flag" , "PULocationID" , "DOLocationID" , "payment_type" , "fare_amount" , "final_amount"]

df11 = df10.reindex(columns=column_names)

# %%
df11
# Out:
#          VendorID new_pickup_date new_dropoff_date new_pickup_time  \
# 0             1.0      2020-10-01       2020-10-01        00:09:19
# 1             1.0      2020-10-01       2020-10-01        00:30:00
# 2             1.0      2020-10-01       2020-10-01        00:31:00
# 3             1.0      2020-10-01       2020-10-01        00:38:44
# 4             1.0      2020-10-01       2020-10-01        00:38:49
# ...           ...             ...              ...             ...
# 1156387       2.0      2020-10-27       2020-10-27        12:44:48
# 1156388       2.0      2020-10-28       2020-10-28        07:52:13
# 1156389       2.0      2020-10-29       2020-10-29        10:50:33
# 1156390       2.0      2020-10-30       2020-10-30        10:40:17
# 1156391       2.0      2020-10-30       2020-10-30        15:35:28
#
#         new_dropoff_time  passenger_count  trip_distance  RatecodeID  \
# 0               00:19:46              1.0           2.00         1.0
# ...

# %%
plt.scatter(df11.final_amount, df11.trip_distance)
plt.xlabel('final_amount')
plt.ylabel('trip_distance')
plt.title('trip_distance vs final_amount')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(15,8))
ax = plt.axes()
corr = df11.corr()
sns.heatmap(corr, fmt='.2f', annot=True, cmap ="YlGnBu")
ax.set_title('Matrix Showing Correlation Between Every Parameters')
plt.show()

# %%
df11.dtypes
# Out:
# VendorID              float64
# new_pickup_date        object
# new_dropoff_date       object
# new_pickup_time        object
# new_dropoff_time       object
# passenger_count       float64
# trip_distance         float64
# RatecodeID            float64
# store_and_fwd_flag     object
# PULocationID            int64
# DOLocationID            int64
# payment_type          float64
# fare_amount           float64
# final_amount          float64
# dtype: object

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
df11.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count 1156392.00000    1156392.00000  1156392.00000 1156392.00000
# mean        1.69457          1.45525        1.45801       1.00302
# std         0.46059          1.05240        0.75779       0.36256
# min         1.00000          1.00000        0.01000       1.00000
# 25%         1.00000          1.00000        0.90000       1.00000
# 50%         2.00000          1.00000        1.32000       1.00000
# 75%         2.00000          1.00000        1.90000       1.00000
# max         2.00000          9.00000       40.61000      99.00000
#
#        PULocationID  DOLocationID  payment_type   fare_amount  final_amount
# count 1156392.00000 1156392.00000 1156392.00000 1156392.00000 1156392.00000
# mean      168.66529     166.81094       1.28115       7.74744      13.35972
# std        66.71650      68.74005       0.46656       2.59603       3.34423
# ...

# %%
passengers = df11['passenger_count'].value_counts().sort_index()
passengers.plot(kind = 'bar',logy = True)
plt.xlabel('Number of passengers')
plt.ylabel('Frequency')
plt.title('Distribution of passenger counts')
plt.show()

# %%
a=df11.groupby('passenger_count').count()['trip_distance']
a.plot()

# %%
ax = sns.boxplot(x="passenger_count", y="trip_distance", data=df11, palette="Set2")

# %%
plt.scatter(df11.final_amount, df11.trip_distance)
plt.xlabel('final_amount')
plt.ylabel('trip_distance')
plt.title('trip_distance vs final_amount')
plt.show()

# %%
#passengers = df11['PULocationID'].value_counts().sort_index()
#passengers.plot(kind = 'bar',logy = True, figsize = (60,30))
plt.hist(df11['PULocationID'], rwidth=0.9)
plt.xlabel('Histogram showing most number of bookings based on area')
plt.ylabel('Frequency')
plt.title('Distribution of booking counts')
plt.show()

# %%
#passengers = df11['DOLocationID'].value_counts().sort_index()
#passengers.plot(kind = 'bar',logy = True, figsize = (60,30))
plt.hist(df11['DOLocationID'], rwidth=0.9)
plt.xlabel('Number of passengers')
plt.ylabel('Frequency')
plt.title('Distribution of passenger drop location counts')
plt.show()

# %%
df11['PULocationID'].value_counts(ascending=True)
# Out:
# 105        1
# 64         1
# 115        1
# 240        1
# 38         1
#        ...
# 239    41572
# 161    43248
# 141    44280
# 236    68485
# 237    73931
# Name: PULocationID, Length: 238, dtype: int64

# %%
df11['DOLocationID'].value_counts(ascending=True)
# Out:
# 178        1
# 172        1
# 27         1
# 245        1
# 11         1
#        ...
# 170    40702
# 161    42170
# 141    43790
# 237    67541
# 236    72062
# Name: DOLocationID, Length: 241, dtype: int64

# %%
df11['passenger_count'].value_counts(ascending=False)
# Out:
# 1.00000    885615
# 2.00000    159805
# 3.00000     41565
# 5.00000     32618
# 6.00000     21332
# 4.00000     15456
# 9.00000         1
# Name: passenger_count, dtype: int64

# %%
def hr_func(ts):
    return ts.hour

pickup_hour = df11['pickup_time_hour'] = df11['new_pickup_time'].apply(hr_func)

print(pickup_hour)
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 1156387    12
# 1156388     7
# 1156389    10
# 1156390    10
# 1156391    15
# Name: new_pickup_time, Length: 1156392, dtype: int64

# %%
plt.hist(pickup_hour, rwidth=0.9, bins=range(0,25))
plt.xlabel('Pickup time')
plt.ylabel('Count')
plt.title('Duration when maximum cabs are booked')
plt.show()

# %%
def hr_func(tu):
    return tu.hour

drop_hour = df11['dropoff_time_hour'] = df11['new_dropoff_time'].apply(hr_func)

print(drop_hour)
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 1156387    12
# 1156388     7
# 1156389    11
# 1156390    10
# 1156391    15
# Name: new_dropoff_time, Length: 1156392, dtype: int64

# %%
plt.hist(drop_hour, rwidth=0.9, bins=range(0,25))
plt.xlabel('Dropoff time')
plt.ylabel('Count')
plt.title('Duration when maximum cab trips are completed')
plt.show()

# %%
x = df11[df11['PULocationID']==236]
x
# Out:
#          VendorID new_pickup_date new_dropoff_date new_pickup_time  \
# 13        1.00000      2020-10-01       2020-10-01        00:13:23
# 120       1.00000      2020-10-01       2020-10-01        01:33:47
# 130       1.00000      2020-10-01       2020-10-01        01:05:41
# 211       1.00000      2020-10-01       2020-10-01        05:54:02
# 212       1.00000      2020-10-01       2020-10-01        05:57:35
# ...           ...             ...              ...             ...
# 1156301   2.00000      2020-10-23       2020-10-23        10:28:35
# 1156378   2.00000      2020-10-09       2020-10-09        12:18:35
# 1156380   2.00000      2020-10-10       2020-10-10        12:12:19
# 1156390   2.00000      2020-10-30       2020-10-30        10:40:17
# 1156391   2.00000      2020-10-30       2020-10-30        15:35:28
#
#         new_dropoff_time  passenger_count  trip_distance  RatecodeID  \
# 13              00:17:58          1.00000        0.60000     1.00000
# ...

# %%
def hr_func(tm):
    return tm.hour

pickup_hour = x['pickup_time_hour'] = x['new_pickup_time'].apply(hr_func)

print(pickup_hour)
# Out:
# 13          0
# 120         1
# 130         1
# 211         5
# 212         5
#            ..
# 1156301    10
# 1156378    12
# 1156380    12
# 1156390    10
# 1156391    15
# Name: new_pickup_time, Length: 68485, dtype: int64
# <ipython-input-51-706ddb9feb09>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pickup_hour = x['pickup_time_hour'] = x['new_pickup_time'].apply(hr_func)

# %%
plt.hist(x['pickup_time_hour'], rwidth=0.9, bins=range(0,25))
plt.xlabel('Pickup time for location id 236')
plt.ylabel('Count')
plt.title('Duration when maximum cabs are booked')
plt.show()
